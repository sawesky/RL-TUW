# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict

# %% [markdown]
# ### 1 - op/wis/rec – Recursive formula for weighted importance sampling for off-policy learning.
#
# In weighted importance sampling, we calculate the estimate:
# \begin{equation*}
#     V_{n + 1}^\pi := \frac{\sum_{k = 1}^n W_k G_k}{\sum_{k = 1}^n W_k}, \;\;\; n \geq 1,
# \end{equation*}
# given the returns $G_1, G_2, ...$ and the weights $W_1, W_2, ...$.
#
# Show that the iteration
# \begin{equation*}
#     V_{n + 1} := V_n + \frac{W_n}{C_n}(G_n - V_n), \;\;\; n \geq 1,
# \end{equation*}
#
# where
#
# \begin{align*}
#     C_0 &= 0 \\
#     C_{n + 1} &:= C_n + W_{n + 1}, \;\;\; n \geq 0
# \end{align*}
#
# yields the same values $V_n^\pi = V_n$ for all $n \in \{2, 3, ...\}$.

# %% [markdown]
# We have $C_0 = 0$ and $C_{n} = \sum_{k = 1}^n W_k$, therefore:
#
# \begin{align*}
#     V_{n + 1} &= \frac{\sum_{k = 1}^n W_k G_k}{C_n} \\
#     V_{n + 1}C_n &= \sum_{k = 1}^n W_k G_k \\
#     V_{n + 1}C_n &= W_n G_n + \sum_{k = 1}^{n - 1} W_k G_k \\
#     V_{n + 1}C_n &= W_n G_n + V_n \sum_{k = 1}^{n - 1} W_k \\
#     V_{n + 1}C_n &= W_n G_n + V_n C_{n - 1} \\
#     V_{n + 1}C_n &= W_n G_n + V_n (C_n - W_n) \\
#     V_{n + 1}C_n &= W_n G_n + V_n C_n - V_n W_n \\
#     V_{n + 1} &= V_n + \frac{W_n}{C_n} (G_n - V_n) \\
#
# \end{align*}

# %% [markdown]
# ### 2 - mc/ctrl/impl – Off-policy MC control (programming).
# Implement off-policy MC control and use it to estimate $\pi_*$ for the grid world in Exercise gw/simple.

# %%
class GridWorld:

    def __init__(self, size = 4, gamma = 1, max_steps = 100):
        
        self.size = size
        self.gamma = gamma
        self.max_steps =  max_steps
        self.terminal_state = [(0, 0), (size - 1, size - 1)]
        self.actions = {
            'up': (-1, 0),
            'down': (1, 0),
            'left': (0, -1),
            'right': (0, 1)
        }
        self.reward = -1
        self.current_step = 0
        self.current_x, self.current_y = self.reset()
        self.policy = self.init_policy()

    def reset(self):

        self.current_step = 0
        while True:
            x = np.random.randint(0, self.size)
            y = np.random.randint(0, self.size)
            if not self.is_terminal((x, y)):
                break
        self.current_x, self.current_y = x, y
        self.done = False
        return x, y

    def print_current_state(self):

        for i in range(0, self.size):
            for j in range(0, self.size):

                if (i, j) in self.terminal_state:
                    print('T', end=' ')
                elif (i, j) == (self.current_x, self.current_y):
                    print('X', end=' ')
                else:
                    print('-', end=' ')

            print()   
    
    def is_terminal(self,  state):

        return state in self.terminal_state
    

    def step(self, action):

        current_state = (self.current_x, self.current_y)

        if (self.is_terminal(current_state)) or (self.current_step >= self.max_steps):
            return 0, True  
        
        dx, dy = self.actions[action]
        new_x = max(0, min(self.size - 1, self.current_x + dx)) # if it hits wall it stays in current state
        new_y = max(0, min(self.size - 1, self.current_y + dy)) # if it hits wall it stays in current state
        new_state = (new_x, new_y)

        if (self.is_terminal(new_state)) or (self.current_step == self.max_steps - 1) : 
            self.done = True

        self.current_x, self.current_y = new_x, new_y 
        self.current_step += 1

        return self.reward, self.done 

    def init_policy(self):

        policy = {}

        for i in range(self.size):
            for j in range(self.size):
                
                if (i, j) not in self.terminal_state:
                    policy[(i, j)] = {action: 1 / len(self.actions) for action in self.actions}
        
        return policy

# %%
grid_world = GridWorld(max_steps = 100) 

current_state = grid_world.current_x, grid_world.current_y
print(f"Initial state: {current_state}")
grid_world.print_current_state()

if (grid_world.is_terminal(current_state)):
   print("Initial state is terminal")
elif (grid_world.max_steps <= 0):
   print("Invalid time steps")

while (not grid_world.is_terminal(current_state)) and (grid_world.current_step < grid_world.max_steps):
    
    action_probabilities = 0.25 * np.ones(4) # equal probabilities for taking actions
    action = np.random.choice(list(grid_world.actions.keys()), p=action_probabilities) 

    reward, done = grid_world.step(action)
    new_state = grid_world.current_x, grid_world.current_y

    print(f"Step {grid_world.current_step}: s {current_state}, a {action} -> s' {new_state}, r {reward}")
    grid_world.print_current_state()

    if done:
        print(f"Terminated after {grid_world.current_step} steps")
        if (grid_world.is_terminal(new_state)):
          print("Terminal state end")
        else:
          print("Max steps end")

    current_state = new_state
# Out:
# Initial state: (1, 3)
# T - - -
# - - - X
# - - - -
# - - - T
# Step 1: s (1, 3), a up -> s' (0, 3), r -1
# T - - X
# - - - -
# - - - -
# - - - T
# Step 2: s (0, 3), a left -> s' (0, 2), r -1
# T - X -
# - - - -
# - - - -
# - - - T
# Step 3: s (0, 2), a left -> s' (0, 1), r -1
# T X - -
# - - - -
# - - - -
# - - - T
# Step 4: s (0, 1), a left -> s' (0, 0), r -1
# T - - -
# - - - -
# - - - -
# - - - T
# Terminated after 4 steps
# Terminal state end

# %%
def off_policy_mc_control(env, num_episodes=200000):
    Q = defaultdict(lambda: {a: np.random.uniform(-1, 1) for a in env.actions})
    C = defaultdict(lambda: {a: 0.0 for a in env.actions})
    target_policy = {}

    actions = list(env.actions.keys())
    epsilon = 0.2

    def behavior_policy(s):
        probs = {a: epsilon / len(actions) for a in actions}
        best_action = max(Q[s], key=lambda a: Q[s][a]) 
        probs[best_action] += 1 - epsilon
        total = sum(probs.values())
        norm_probs = [probs[a] / total for a in actions]

        a = np.random.choice(actions, p=norm_probs)
        return a, probs[a]

    for _ in range(num_episodes):
        episode = []
        env.reset()

        for _ in range(env.max_steps):
            s = (env.current_x, env.current_y)
            a, prob = behavior_policy(s)
            r, done = env.step(a)
            episode.append((s, a, r, prob))
            if done:
                break

        G = 0
        W = 1

        for s, a, r, b_prob in reversed(episode):
            G = env.gamma * G + r
            C[s][a] += W
            Q[s][a] += (W / C[s][a]) * (G - Q[s][a])

            target_policy[s] = max(Q[s], key=Q[s].get)

            if a != target_policy[s]:
                break
            if b_prob == 0:  # prevent divide-by-zero
                break
            W /= b_prob

    return target_policy, Q

# %%
env = GridWorld()
policy, Q = off_policy_mc_control(env)

# Print greedy policy
for i in range(env.size):
    for j in range(env.size):
        s = (i, j)
        if s in env.terminal_state:
            print("T", end="  ")
        else:
            print(policy.get(s, "-")[0].upper(), end="  ")
    print()
# Out:
# T  L  U  U
# U  U  U  D
# U  U  D  D
# D  R  R  T

# %%
for i in range(env.size):
    for j in range(env.size):
        s = (i, j)
        if s in Q:
            q_vals = Q[s]
            best_q = max(q_vals.values())
            print(f"{best_q:5.1f}", end=" ")
        else:
            print("  N/A", end=" ")
    print()
# Out:
#   N/A  -1.0  -1.3  -1.9
#  -1.0  -2.0  -2.0  -2.0
#  -2.0  -3.0  -2.0  -1.0
#  -2.4  -2.0  -1.0   N/A

# %% [markdown]
# ### 3. mc/ctrl/ratio – Importance-sampling ratio in off-policy MC control.
#
# In the off-policy MC-control algorithm in [1, Section 5.7], the importance sampling ratio is updated according to
#
# \begin{equation*}
#     W := \frac{W}{b(A_t|S_t)}
# \end{equation*}
#
# although the definition of the importance-sampling ratio $\rho_{t:T-1}$ implies
#
# \begin{equation*}
#     W := \frac{\pi(A_t|S_t)}{b(A_t|S_t)}W
# \end{equation*}
#
# Why is the update in the algorithm nevertheless correct?

# %% [markdown]
# In the off-policy MC algorithm target policy $\pi$ is deterministic and greedy:
#
# \begin{equation*}
#     \pi(A_t | S_t) = \begin{cases}
#                         1, \;\; \text{if} A_t = \argmax_{a} Q(S_t, a) \\
#                         0, \;\; \text{otherwise}
#                      \end{cases}
# \end{equation*}
#
# So for the trajectory to contribute to learning, the actions must match the greedy policy. If $A_t \neq \argmax_{a} Q(S_t, a)$, then the importance weight becomes zero and the episode's return is ignored beyond that point. But when the action matches greedy policy we have $\pi(A_t | S_t) = 1$ and update becomes:
#
# \begin{equation*}
#     W := \frac{1}{b(A_t|S_t)}W
# \end{equation*}

# %% [markdown]
# ### 4. impl – Windy Grid World.
#
# Implement Windy Grid World (see Section 2.4.2).

# %%
class WindyGridWorld:

    def __init__(self, width=10, height=7, gamma=1, max_steps=100):
        self.width = width
        self.height = height
        self.gamma = gamma
        self.max_steps = max_steps
        self.terminal_state = (3, 7)  # default from Sutton's book
        self.start_state = (3, 0)

        self.wind = {3: 1, 4: 1, 5: 1, 6: 2, 7: 2, 8: 1}  # wind strength by column

        self.actions = {
            'up': (-1, 0),
            'down': (1, 0),
            'left': (0, -1),
            'right': (0, 1)
        }
        self.reward = -1
        self.current_step = 0
        self.current_x, self.current_y = self.reset()
        self.policy = self.init_policy()

    def reset(self):
        self.current_step = 0
        self.done = False
        self.current_x, self.current_y = self.start_state
        return self.current_x, self.current_y

    def is_terminal(self, state):
        return state == self.terminal_state

    def step(self, action):

        current_state = (self.current_x, self.current_y)
        if (self.is_terminal(current_state)) or (self.current_step >= self.max_steps):
            return 0, True

        dx, dy = self.actions[action]
        new_x = self.current_x + dx
        new_y = self.current_y + dy

        # Apply wind (vertical movement)
        wind_strength = self.wind.get(new_y, 0)
        new_x -= wind_strength  # wind pushes up

        # Clamp to grid boundaries
        new_x = max(0, min(self.height - 1, new_x))
        new_y = max(0, min(self.width - 1, new_y))

        self.current_x, self.current_y = new_x, new_y
        self.current_step += 1

        if self.is_terminal((new_x, new_y)) or self.current_step >= self.max_steps:
            self.done = True

        return self.reward, self.done

    def print_current_state(self):
        for i in range(self.height):
            for j in range(self.width):
                if (i, j) == self.terminal_state:
                    print('T', end=' ')
                elif (i, j) == (self.current_x, self.current_y):
                    print('X', end=' ')
                else:
                    print('-', end=' ')
            print()

    def init_policy(self):
        policy = {}
        for i in range(self.height):
            for j in range(self.width):
                if (i, j) != self.terminal_state:
                    policy[(i, j)] = {a: 1 / len(self.actions) for a in self.actions}
        return policy

# %%
grid_world = WindyGridWorld(max_steps = 50000) 

current_state = grid_world.current_x, grid_world.current_y
print(f"Initial state: {current_state}")
grid_world.print_current_state()

if (grid_world.is_terminal(current_state)):
   print("Initial state is terminal")
elif (grid_world.max_steps <= 0):
   print("Invalid time steps")

while (not grid_world.is_terminal(current_state)) and (grid_world.current_step < grid_world.max_steps):
    
    action_probabilities = 0.25 * np.ones(4) # equal probabilities for taking actions
    action = np.random.choice(list(grid_world.actions.keys()), p=action_probabilities) 

    reward, done = grid_world.step(action)
    new_state = grid_world.current_x, grid_world.current_y

    print(f"Step {grid_world.current_step}: s {current_state}, a {action} -> s' {new_state}, r {reward}")
    grid_world.print_current_state()

    if done:
        print(f"Terminated after {grid_world.current_step} steps")
        if (grid_world.is_terminal(new_state)):
          print("Terminal state end")
        else:
          print("Max steps end")

    current_state = new_state
# Out:
# Initial state: (3, 0)
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 1: s (3, 0), a up -> s' (2, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 2: s (2, 0), a left -> s' (2, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 3: s (2, 0), a left -> s' (2, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4: s (2, 0), a left -> s' (2, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 5: s (2, 0), a right -> s' (2, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 6: s (2, 1), a down -> s' (3, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 7: s (3, 1), a right -> s' (3, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - X - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 8: s (3, 2), a down -> s' (4, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 9: s (4, 2), a left -> s' (4, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 10: s (4, 1), a right -> s' (4, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 11: s (4, 2), a up -> s' (3, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - X - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 12: s (3, 2), a left -> s' (3, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 13: s (3, 1), a left -> s' (3, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 14: s (3, 0), a down -> s' (4, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 15: s (4, 0), a up -> s' (3, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 16: s (3, 0), a up -> s' (2, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 17: s (2, 0), a right -> s' (2, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 18: s (2, 1), a right -> s' (2, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 19: s (2, 2), a down -> s' (3, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - X - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 20: s (3, 2), a down -> s' (4, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 21: s (4, 2), a up -> s' (3, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - X - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 22: s (3, 2), a right -> s' (2, 3), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - X - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 23: s (2, 3), a left -> s' (2, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 24: s (2, 2), a right -> s' (1, 3), r -1
# - - - - - - - - - -
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 25: s (1, 3), a down -> s' (1, 3), r -1
# - - - - - - - - - -
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 26: s (1, 3), a up -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 27: s (0, 3), a right -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 28: s (0, 4), a left -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 29: s (0, 3), a right -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 30: s (0, 4), a left -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 31: s (0, 3), a up -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 32: s (0, 3), a down -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 33: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 34: s (0, 2), a up -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 35: s (0, 2), a up -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 36: s (0, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 37: s (0, 3), a up -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 38: s (0, 3), a right -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 39: s (0, 4), a left -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 40: s (0, 3), a down -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 41: s (0, 3), a down -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 42: s (0, 3), a up -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 43: s (0, 3), a right -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 44: s (0, 4), a right -> s' (0, 5), r -1
# - - - - - X - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 45: s (0, 5), a left -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 46: s (0, 4), a left -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 47: s (0, 3), a down -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 48: s (0, 3), a down -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 49: s (0, 3), a down -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 50: s (0, 3), a right -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 51: s (0, 4), a left -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 52: s (0, 3), a right -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 53: s (0, 4), a up -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 54: s (0, 4), a left -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 55: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 56: s (0, 2), a down -> s' (1, 2), r -1
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 57: s (1, 2), a left -> s' (1, 1), r -1
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 58: s (1, 1), a right -> s' (1, 2), r -1
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 59: s (1, 2), a up -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 60: s (0, 2), a left -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 61: s (0, 1), a down -> s' (1, 1), r -1
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 62: s (1, 1), a down -> s' (2, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 63: s (2, 1), a right -> s' (2, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 64: s (2, 2), a up -> s' (1, 2), r -1
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 65: s (1, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 66: s (0, 3), a down -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 67: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 68: s (0, 2), a down -> s' (1, 2), r -1
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 69: s (1, 2), a left -> s' (1, 1), r -1
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 70: s (1, 1), a right -> s' (1, 2), r -1
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 71: s (1, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 72: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 73: s (0, 2), a left -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 74: s (0, 1), a up -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 75: s (0, 1), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 76: s (0, 0), a right -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 77: s (0, 1), a down -> s' (1, 1), r -1
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 78: s (1, 1), a up -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 79: s (0, 1), a right -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 80: s (0, 2), a left -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 81: s (0, 1), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 82: s (0, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 83: s (0, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 84: s (0, 0), a down -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 85: s (1, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 86: s (0, 0), a down -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 87: s (1, 0), a down -> s' (2, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 88: s (2, 0), a left -> s' (2, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 89: s (2, 0), a up -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 90: s (1, 0), a left -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 91: s (1, 0), a left -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 92: s (1, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 93: s (0, 0), a down -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 94: s (1, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 95: s (0, 0), a down -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 96: s (1, 0), a left -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 97: s (1, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 98: s (0, 0), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 99: s (0, 0), a right -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 100: s (0, 1), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 101: s (0, 0), a down -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 102: s (1, 0), a down -> s' (2, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 103: s (2, 0), a left -> s' (2, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 104: s (2, 0), a left -> s' (2, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 105: s (2, 0), a up -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 106: s (1, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 107: s (0, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 108: s (0, 0), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 109: s (0, 0), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 110: s (0, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 111: s (0, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 112: s (0, 0), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 113: s (0, 0), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 114: s (0, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 115: s (0, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 116: s (0, 0), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 117: s (0, 0), a right -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 118: s (0, 1), a up -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 119: s (0, 1), a up -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 120: s (0, 1), a down -> s' (1, 1), r -1
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 121: s (1, 1), a right -> s' (1, 2), r -1
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 122: s (1, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 123: s (0, 3), a up -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 124: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 125: s (0, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 126: s (0, 3), a up -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 127: s (0, 3), a down -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 128: s (0, 3), a down -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 129: s (0, 3), a down -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 130: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 131: s (0, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 132: s (0, 3), a up -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 133: s (0, 3), a up -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 134: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 135: s (0, 2), a down -> s' (1, 2), r -1
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 136: s (1, 2), a left -> s' (1, 1), r -1
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 137: s (1, 1), a up -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 138: s (0, 1), a up -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 139: s (0, 1), a down -> s' (1, 1), r -1
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 140: s (1, 1), a up -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 141: s (0, 1), a down -> s' (1, 1), r -1
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 142: s (1, 1), a left -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 143: s (1, 0), a right -> s' (1, 1), r -1
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 144: s (1, 1), a right -> s' (1, 2), r -1
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 145: s (1, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 146: s (0, 3), a down -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 147: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 148: s (0, 2), a up -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 149: s (0, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 150: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 151: s (0, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 152: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 153: s (0, 2), a left -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 154: s (0, 1), a down -> s' (1, 1), r -1
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 155: s (1, 1), a down -> s' (2, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 156: s (2, 1), a down -> s' (3, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 157: s (3, 1), a down -> s' (4, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 158: s (4, 1), a left -> s' (4, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 159: s (4, 0), a right -> s' (4, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 160: s (4, 1), a right -> s' (4, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 161: s (4, 2), a right -> s' (3, 3), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - X - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 162: s (3, 3), a down -> s' (3, 3), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - X - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 163: s (3, 3), a left -> s' (3, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - X - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 164: s (3, 2), a left -> s' (3, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 165: s (3, 1), a left -> s' (3, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 166: s (3, 0), a down -> s' (4, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 167: s (4, 0), a right -> s' (4, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 168: s (4, 1), a up -> s' (3, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 169: s (3, 1), a left -> s' (3, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 170: s (3, 0), a left -> s' (3, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 171: s (3, 0), a down -> s' (4, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 172: s (4, 0), a down -> s' (5, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# Step 173: s (5, 0), a down -> s' (6, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# Step 174: s (6, 0), a down -> s' (6, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# Step 175: s (6, 0), a up -> s' (5, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# Step 176: s (5, 0), a down -> s' (6, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# Step 177: s (6, 0), a left -> s' (6, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# Step 178: s (6, 0), a right -> s' (6, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - - - -
# Step 179: s (6, 1), a left -> s' (6, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# Step 180: s (6, 0), a right -> s' (6, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - - - -
# Step 181: s (6, 1), a down -> s' (6, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - - - -
# Step 182: s (6, 1), a down -> s' (6, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - - - -
# Step 183: s (6, 1), a down -> s' (6, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - - - -
# Step 184: s (6, 1), a left -> s' (6, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# Step 185: s (6, 0), a right -> s' (6, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - - - -
# Step 186: s (6, 1), a right -> s' (6, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - X - - - - - - -
# Step 187: s (6, 2), a right -> s' (5, 3), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - X - - - - - -
# - - - - - - - - - -
# Step 188: s (5, 3), a up -> s' (3, 3), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - X - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 189: s (3, 3), a down -> s' (3, 3), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - X - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 190: s (3, 3), a down -> s' (3, 3), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - X - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 191: s (3, 3), a right -> s' (2, 4), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - X - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 192: s (2, 4), a down -> s' (2, 4), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - X - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 193: s (2, 4), a left -> s' (1, 3), r -1
# - - - - - - - - - -
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 194: s (1, 3), a right -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 195: s (0, 4), a left -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 196: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 197: s (0, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 198: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 199: s (0, 2), a down -> s' (1, 2), r -1
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 200: s (1, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 201: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 202: s (0, 2), a down -> s' (1, 2), r -1
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 203: s (1, 2), a left -> s' (1, 1), r -1
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 204: s (1, 1), a left -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 205: s (1, 0), a down -> s' (2, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 206: s (2, 0), a right -> s' (2, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 207: s (2, 1), a left -> s' (2, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 208: s (2, 0), a right -> s' (2, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 209: s (2, 1), a up -> s' (1, 1), r -1
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 210: s (1, 1), a up -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 211: s (0, 1), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 212: s (0, 0), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 213: s (0, 0), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 214: s (0, 0), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 215: s (0, 0), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 216: s (0, 0), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 217: s (0, 0), a down -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 218: s (1, 0), a down -> s' (2, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 219: s (2, 0), a up -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 220: s (1, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 221: s (0, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 222: s (0, 0), a down -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 223: s (1, 0), a down -> s' (2, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 224: s (2, 0), a down -> s' (3, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 225: s (3, 0), a down -> s' (4, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 226: s (4, 0), a right -> s' (4, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 227: s (4, 1), a down -> s' (5, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# Step 228: s (5, 1), a right -> s' (5, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - - - -
# Step 229: s (5, 2), a right -> s' (4, 3), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 230: s (4, 3), a left -> s' (4, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 231: s (4, 2), a up -> s' (3, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - X - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 232: s (3, 2), a left -> s' (3, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 233: s (3, 1), a down -> s' (4, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 234: s (4, 1), a up -> s' (3, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 235: s (3, 1), a down -> s' (4, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 236: s (4, 1), a up -> s' (3, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 237: s (3, 1), a left -> s' (3, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 238: s (3, 0), a left -> s' (3, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 239: s (3, 0), a left -> s' (3, 0), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# X - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 240: s (3, 0), a right -> s' (3, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 241: s (3, 1), a up -> s' (2, 1), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 242: s (2, 1), a right -> s' (2, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 243: s (2, 2), a right -> s' (1, 3), r -1
# - - - - - - - - - -
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 244: s (1, 3), a down -> s' (1, 3), r -1
# - - - - - - - - - -
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 245: s (1, 3), a up -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 246: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 247: s (0, 2), a down -> s' (1, 2), r -1
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 248: s (1, 2), a down -> s' (2, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 249: s (2, 2), a down -> s' (3, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# ...
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4292: s (2, 2), a down -> s' (3, 2), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - X - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4293: s (3, 2), a right -> s' (2, 3), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - X - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4294: s (2, 3), a right -> s' (1, 4), r -1
# - - - - - - - - - -
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4295: s (1, 4), a left -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4296: s (0, 3), a down -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4297: s (0, 3), a up -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4298: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4299: s (0, 2), a left -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4300: s (0, 1), a down -> s' (1, 1), r -1
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4301: s (1, 1), a left -> s' (1, 0), r -1
# - - - - - - - - - -
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4302: s (1, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4303: s (0, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4304: s (0, 0), a left -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4305: s (0, 0), a up -> s' (0, 0), r -1
# X - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4306: s (0, 0), a right -> s' (0, 1), r -1
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4307: s (0, 1), a down -> s' (1, 1), r -1
# - - - - - - - - - -
# - X - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4308: s (1, 1), a right -> s' (1, 2), r -1
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4309: s (1, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4310: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4311: s (0, 2), a up -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4312: s (0, 2), a down -> s' (1, 2), r -1
# - - - - - - - - - -
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4313: s (1, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4314: s (0, 3), a up -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4315: s (0, 3), a up -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4316: s (0, 3), a right -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4317: s (0, 4), a down -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4318: s (0, 4), a down -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4319: s (0, 4), a down -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4320: s (0, 4), a left -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4321: s (0, 3), a down -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4322: s (0, 3), a right -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4323: s (0, 4), a left -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4324: s (0, 3), a up -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4325: s (0, 3), a up -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4326: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4327: s (0, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4328: s (0, 3), a down -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4329: s (0, 3), a right -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4330: s (0, 4), a up -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4331: s (0, 4), a down -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4332: s (0, 4), a down -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4333: s (0, 4), a up -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4334: s (0, 4), a down -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4335: s (0, 4), a left -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4336: s (0, 3), a left -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4337: s (0, 2), a up -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4338: s (0, 2), a up -> s' (0, 2), r -1
# - - X - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4339: s (0, 2), a right -> s' (0, 3), r -1
# - - - X - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4340: s (0, 3), a right -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4341: s (0, 4), a right -> s' (0, 5), r -1
# - - - - - X - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4342: s (0, 5), a right -> s' (0, 6), r -1
# - - - - - - X - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4343: s (0, 6), a left -> s' (0, 5), r -1
# - - - - - X - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4344: s (0, 5), a left -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4345: s (0, 4), a down -> s' (0, 4), r -1
# - - - - X - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4346: s (0, 4), a right -> s' (0, 5), r -1
# - - - - - X - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4347: s (0, 5), a right -> s' (0, 6), r -1
# - - - - - - X - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4348: s (0, 6), a down -> s' (0, 6), r -1
# - - - - - - X - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4349: s (0, 6), a right -> s' (0, 7), r -1
# - - - - - - - X - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4350: s (0, 7), a down -> s' (0, 7), r -1
# - - - - - - - X - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4351: s (0, 7), a right -> s' (0, 8), r -1
# - - - - - - - - X -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4352: s (0, 8), a down -> s' (0, 8), r -1
# - - - - - - - - X -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4353: s (0, 8), a right -> s' (0, 9), r -1
# - - - - - - - - - X
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4354: s (0, 9), a down -> s' (1, 9), r -1
# - - - - - - - - - -
# - - - - - - - - - X
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4355: s (1, 9), a left -> s' (0, 8), r -1
# - - - - - - - - X -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4356: s (0, 8), a up -> s' (0, 8), r -1
# - - - - - - - - X -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4357: s (0, 8), a down -> s' (0, 8), r -1
# - - - - - - - - X -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4358: s (0, 8), a right -> s' (0, 9), r -1
# - - - - - - - - - X
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4359: s (0, 9), a down -> s' (1, 9), r -1
# - - - - - - - - - -
# - - - - - - - - - X
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4360: s (1, 9), a up -> s' (0, 9), r -1
# - - - - - - - - - X
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4361: s (0, 9), a down -> s' (1, 9), r -1
# - - - - - - - - - -
# - - - - - - - - - X
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4362: s (1, 9), a down -> s' (2, 9), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - X
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4363: s (2, 9), a up -> s' (1, 9), r -1
# - - - - - - - - - -
# - - - - - - - - - X
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4364: s (1, 9), a right -> s' (1, 9), r -1
# - - - - - - - - - -
# - - - - - - - - - X
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4365: s (1, 9), a down -> s' (2, 9), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - X
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4366: s (2, 9), a down -> s' (3, 9), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - X
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4367: s (3, 9), a down -> s' (4, 9), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - X
# - - - - - - - - - -
# - - - - - - - - - -
# Step 4368: s (4, 9), a down -> s' (5, 9), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - X
# - - - - - - - - - -
# Step 4369: s (5, 9), a down -> s' (6, 9), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - X
# Step 4370: s (6, 9), a left -> s' (5, 8), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - X -
# - - - - - - - - - -
# Step 4371: s (5, 8), a down -> s' (5, 8), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - X -
# - - - - - - - - - -
# Step 4372: s (5, 8), a down -> s' (5, 8), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - X -
# - - - - - - - - - -
# Step 4373: s (5, 8), a left -> s' (3, 7), r -1
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - T - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# Terminated after 4373 steps
# Terminal state end

# %% [markdown]
# ### 5. impl – Cliff Walking
# Implement Cliff Walking (see Section 2.4.3).

# %%
class CliffWalking:
    def __init__(self, width=12, height=4):
        self.height = height
        self.width = width
        self.start = (height - 1, 0)
        self.goal = (height - 1, width - 1)
        self.cliff = [(height - 1, i) for i in range(1, width - 1)]  # the cliff region
        self.actions = ['up', 'down', 'left', 'right'] 
        self.state = self.start # current state
        self.rewards = -1  # constant reward of -1 for each step
        self.state_values = np.zeros((width, height))
        self.action_space = len(self.actions)

    def reset(self):
        self.state = self.start
        return self.state

    def is_terminal(self, state):
        return state == self.goal

    def step(self, action): # make one step in the environment S_t, A_t -> R_t, S'_t
        if self.state in self.cliff:
            return self.start, -100  # if you step on a cliff -> go back to the start with -100 reward 

        # calculate next position based on current state and action
        x, y = self.state
        if action == 'up':
            x = max(x - 1, 0)
        elif action == 'down':
            x = min(x + 1, self.height - 1)
        elif action == 'left':
            y = max(y - 1, 0)
        elif action == 'right':
            y = min(y + 1, self.width - 1)

        next_state = (x, y)
        # check if the next state is the cliff
        if next_state in self.cliff:
            self.reset()
            return self.start, -100

        self.state = next_state
        return next_state, self.rewards # const -1

# %%
def run_episode(gridworld, max_trials):
    state = gridworld.reset() # come to the start
    total_reward = 0
    steps = []
    while not gridworld.is_terminal(state): # as long as the goal isn't reached
        action = np.random.choice(gridworld.actions)  # random policy for demonstration
        next_state, reward = gridworld.step(action)
        total_reward += reward
        steps.append((state, action))
        state = next_state
        if state == gridworld.start and reward == -100:
            print("Fell into the cliff, back to start. Current reward: ", total_reward)
        if gridworld.is_terminal(state):
            print("Reached goal, episode ends. Final reward: ", total_reward)
            break
        # not cliff, not goal -> just continue moving
    return total_reward, steps

cliff_grid_world = CliffWalking(width=12, height=4)
episode_reward, steps = run_episode(cliff_grid_world, max_trials=20)
# Out:
# Fell into the cliff, back to start. Current reward:  -107
# Fell into the cliff, back to start. Current reward:  -246
# Fell into the cliff, back to start. Current reward:  -350
# Fell into the cliff, back to start. Current reward:  -466
# Fell into the cliff, back to start. Current reward:  -567
# Fell into the cliff, back to start. Current reward:  -671
# Fell into the cliff, back to start. Current reward:  -772
# Fell into the cliff, back to start. Current reward:  -874
# Fell into the cliff, back to start. Current reward:  -981
# Fell into the cliff, back to start. Current reward:  -1117
# Fell into the cliff, back to start. Current reward:  -1219
# Fell into the cliff, back to start. Current reward:  -1324
# Fell into the cliff, back to start. Current reward:  -1483
# Fell into the cliff, back to start. Current reward:  -1589
# Fell into the cliff, back to start. Current reward:  -1708
# Fell into the cliff, back to start. Current reward:  -1808
# Fell into the cliff, back to start. Current reward:  -1911
# Fell into the cliff, back to start. Current reward:  -2011
# Fell into the cliff, back to start. Current reward:  -2134
# Fell into the cliff, back to start. Current reward:  -2236
# Fell into the cliff, back to start. Current reward:  -93838
# Fell into the cliff, back to start. Current reward:  -93938
# Fell into the cliff, back to start. Current reward:  -94074
# Fell into the cliff, back to start. Current reward:  -94214
# Fell into the cliff, back to start. Current reward:  -94314
# Fell into the cliff, back to start. Current reward:  -94417
# Fell into the cliff, back to start. Current reward:  -94521
# Fell into the cliff, back to start. Current reward:  -94622
# Fell into the cliff, back to start. Current reward:  -94722
# Fell into the cliff, back to start. Current reward:  -94823
# Fell into the cliff, back to start. Current reward:  -94925
# Fell into the cliff, back to start. Current reward:  -95025
# Fell into the cliff, back to start. Current reward:  -95134
# Fell into the cliff, back to start. Current reward:  -95234
# Fell into the cliff, back to start. Current reward:  -95336
# Fell into the cliff, back to start. Current reward:  -95474
# Fell into the cliff, back to start. Current reward:  -95579
# Fell into the cliff, back to start. Current reward:  -95686
# Fell into the cliff, back to start. Current reward:  -95792
# Fell into the cliff, back to start. Current reward:  -95892
# Fell into the cliff, back to start. Current reward:  -95994
# Fell into the cliff, back to start. Current reward:  -96094
# Fell into the cliff, back to start. Current reward:  -96195
# Fell into the cliff, back to start. Current reward:  -96296
# Fell into the cliff, back to start. Current reward:  -96397
# Fell into the cliff, back to start. Current reward:  -96500
# Fell into the cliff, back to start. Current reward:  -96605
# Fell into the cliff, back to start. Current reward:  -96705
# Fell into the cliff, back to start. Current reward:  -96805
# Fell into the cliff, back to start. Current reward:  -96929
# Fell into the cliff, back to start. Current reward:  -97059
# Fell into the cliff, back to start. Current reward:  -97187
# Fell into the cliff, back to start. Current reward:  -97328
# Fell into the cliff, back to start. Current reward:  -97428
# Fell into the cliff, back to start. Current reward:  -97533
# Fell into the cliff, back to start. Current reward:  -97635
# Fell into the cliff, back to start. Current reward:  -97736
# Fell into the cliff, back to start. Current reward:  -97836
# Reached goal, episode ends. Final reward:  -97864

# %% [markdown]
# ### 6. impl - Frozen Lake.
#
# Implement Frozen Lake (see Section 2.4.4).

# %%
class FrozenLake:

    def __init__(self, size=4, gamma=1.0, max_steps=100, slip=True):
        self.size = size
        self.gamma = gamma
        self.max_steps = max_steps
        self.slip = slip

        self.actions = {
            'up': (-1, 0),
            'down': (1, 0),
            'left': (0, -1),
            'right': (0, 1)
        }

        self.frozen = [(i, j) for i in range(size) for j in range(size)]
        self.holes = [(1, 1), (1, 3), (3, 0), (2, 3)]  # classic layout
        self.goal = (3, 3)
        self.start_state = (0, 0)
        for tile in self.holes + [self.goal]:
            if tile in self.frozen:
                self.frozen.remove(tile)

        self.current_step = 0
        self.current_x, self.current_y = self.reset()
        self.done = False
        self.policy = self.init_policy()

    def reset(self):
        self.current_step = 0
        self.done = False
        self.current_x, self.current_y = self.start_state
        return self.current_x, self.current_y

    def is_terminal(self, state):
        return state in self.holes or state == self.goal

    def perpendicular_actions(self, action):
        if action in ['up', 'down']:
            return ['left', 'right']
        else:
            return ['up', 'down']
        
    def step(self, action):
        if self.done or self.current_step >= self.max_steps:
            return 0, True

        if self.slip:
            all_options = [action] + self.perpendicular_actions(action)
            action = np.random.choice(all_options, p=[1/3, 1/3, 1/3])

        dx, dy = self.actions[action]
        new_x = max(0, min(self.size - 1, self.current_x + dx))
        new_y = max(0, min(self.size - 1, self.current_y + dy))
        new_state = (new_x, new_y)

        self.current_x, self.current_y = new_x, new_y
        self.current_step += 1

        if new_state in self.holes:
            self.done = True
            return 0, True
        elif new_state == self.goal:
            self.done = True
            return 1, True
        elif self.current_step >= self.max_steps:
            self.done = True
            return 0, True

        return 0, False

    def print_current_state(self):
        for i in range(self.size):
            for j in range(self.size):
                pos = (i, j)
                if pos == (self.current_x, self.current_y):
                    print('X', end=' ')
                elif pos in self.holes:
                    print('H', end=' ')
                elif pos == self.goal:
                    print('G', end=' ')
                else:
                    print('-', end=' ')
            print()

    def init_policy(self):
        policy = {}
        for i in range(self.size):
            for j in range(self.size):
                if (i, j) not in self.holes and (i, j) != self.goal:
                    policy[(i, j)] = {a: 1 / len(self.actions) for a in self.actions}
        return policy

# %%
grid_world = FrozenLake(max_steps = 10000) 

current_state = grid_world.current_x, grid_world.current_y
print(f"Initial state: {current_state}")
grid_world.print_current_state()

if (grid_world.is_terminal(current_state)):
   print("Initial state is terminal")
elif (grid_world.max_steps <= 0):
   print("Invalid time steps")

while (not grid_world.is_terminal(current_state)) and (grid_world.current_step < grid_world.max_steps):
    
    action_probabilities = 0.25 * np.ones(4) # equal probabilities for taking actions
    action = np.random.choice(list(grid_world.actions.keys()), p=action_probabilities) 

    reward, done = grid_world.step(action)
    new_state = grid_world.current_x, grid_world.current_y

    print(f"Step {grid_world.current_step}: s {current_state}, a {action} -> s' {new_state}, r {reward}")
    grid_world.print_current_state()

    if done:
        print(f"Terminated after {grid_world.current_step} steps")
        if (grid_world.is_terminal(new_state)):
          print("Terminal state end")
        else:
          print("Max steps end")

    current_state = new_state
# Out:
# Initial state: (0, 0)
# X - - -
# - H - H
# - - - H
# H - - G
# Step 1: s (0, 0), a up -> s' (0, 0), r 0
# X - - -
# - H - H
# - - - H
# H - - G
# Step 2: s (0, 0), a down -> s' (1, 0), r 0
# - - - -
# X H - H
# - - - H
# H - - G
# Step 3: s (1, 0), a down -> s' (1, 1), r 0
# - - - -
# - X - H
# - - - H
# H - - G
# Terminated after 3 steps
# Terminal state end

# %% [markdown]
# ### 7. impl – Blackjack.
# Implement Blackjack (see Section 2.4.5).

# %%
class BlackjackEnv:

    def __init__(self, gamma=1.0, max_steps=100):
        self.gamma = gamma
        self.max_steps = max_steps
        self.actions = {
            'hit': 0,
            'stick': 1
        }
        self.action_list = list(self.actions.keys())

        self.done = False
        self.current_step = 0
        self.reset()
        self.policy = self.init_policy()

    def draw_card(self):
        card = np.random.randint(1, 14)
        return min(card, 10)  # JQK cards = 10

    def draw_hand(self):
        return [self.draw_card(), self.draw_card()]

    def usable_ace(self, hand):
        return 1 in hand and sum(hand) + 10 <= 21

    def sum_hand(self, hand):
        total = sum(hand)
        if self.usable_ace(hand):
            return total + 10
        return total

    def is_bust(self, hand):
        return self.sum_hand(hand) > 21

    def has_natural(self, hand):
        return sorted(hand) == [1, 10]

    def reset(self):
        self.player = self.draw_hand()
        self.dealer = self.draw_hand()
        self.done = False
        self.current_step = 0

        # check natural
        if self.has_natural(self.player):
            if self.has_natural(self.dealer):
                self.done = True
                self.reward = 0
            else:
                self.done = True
                self.reward = 1
        else:
            self.reward = 0

        return self.get_state()

    def step(self, action):
        if self.done:
            return self.reward, True

        if action == 'hit':
            self.player.append(self.draw_card())
            self.current_step += 1
            if self.is_bust(self.player):
                self.done = True
                self.reward = -1
        else: 
            self.done = True
            # dealers turn
            while self.sum_hand(self.dealer) < 17:
                self.dealer.append(self.draw_card())

            player_sum = self.sum_hand(self.player)
            dealer_sum = self.sum_hand(self.dealer)

            if self.is_bust(self.dealer):
                self.reward = 1
            elif dealer_sum > player_sum:
                self.reward = -1
            elif dealer_sum < player_sum:
                self.reward = 1
            else:
                self.reward = 0

        return self.reward, self.done

    def get_state(self):
        return (self.sum_hand(self.player),
                self.dealer[0],
                self.usable_ace(self.player))

    def print_current_state(self):
        player_sum = self.sum_hand(self.player)
        usable = self.usable_ace(self.player)
        print(f"Player hand: {self.player} (sum={player_sum}, usable_ace={usable})")
        print(f"Dealer showing: {self.dealer[0]}")
        if self.done:
            print(f"Dealer full hand: {self.dealer} (sum={self.sum_hand(self.dealer)})")

    def init_policy(self):
        policy = {}
        for total in range(12, 22):  # below 12 always hit
            for dealer_card in range(1, 11):
                for usable in [True, False]:
                    policy[(total, dealer_card, usable)] = {
                        a: 1 / len(self.actions) for a in self.actions
                    }
        return policy

# %%
env = BlackjackEnv()
state = env.get_state()
print("Initial state:", state)
env.print_current_state()

while not env.done:
    print("-------------------------")
    action = np.random.choice(['hit', 'stick']) # random play
    reward, done = env.step(action)
    env.print_current_state()
    print(f"Action: {action}, Reward: {reward}")
# Out:
# Initial state: (13, 6, False)
# Player hand: [3, 10] (sum=13, usable_ace=False)
# Dealer showing: 6
# -------------------------
# Player hand: [3, 10, 2] (sum=15, usable_ace=False)
# Dealer showing: 6
# Action: hit, Reward: 0
# -------------------------
# Player hand: [3, 10, 2] (sum=15, usable_ace=False)
# Dealer showing: 6
# Dealer full hand: [6, 2, 2, 1] (sum=21)
# Action: stick, Reward: -1

# %% [markdown]
# ### 8. impl – Autoregressive Trend Process.
# Implement an autoregressive trend process (see Section 2.4.7).

# %%
class AutoregressiveStockEnv:

    def __init__(self, length=100, lam=3, kappa=0.9, gamma=1.0, max_steps=99):
        self.length = length
        self.lam = lam
        self.kappa = kappa
        self.gamma = gamma
        self.max_steps = max_steps

        self.actions = {
            'short': -1,
            'neutral': 0,
            'long': 1
        }

        self.reward = 0
        self.prices = []
        self.current_step = 0
        self.done = False

        self.generate_prices()
        self.reset()
        self.policy = self.init_policy()

    def generate_prices(self):
        a = [1.0]
        b = [np.random.normal(0, 1)]

        for k in range(1, self.length):
            a_k = a[-1] + b[-1] + self.lam * np.random.normal(0, 1)
            b_k = self.kappa * b[-1] + np.random.normal(0, 1)
            a.append(a_k)
            b.append(b_k)

        a = np.array(a)
        scaled = a / (np.max(a) - np.min(a))
        self.prices = np.exp(scaled)

    def reset(self):
        self.current_step = 0
        self.done = False
        self.position = 0  # 0 = neutral, -1 = short, 1 = long
        return self.get_state()

    def get_state(self):
        return (self.current_step, self.position)

    def step(self, action):
        if self.done or self.current_step >= self.max_steps:
            return 0, True

        next_step = self.current_step + 1
        price_change = self.prices[next_step] - self.prices[self.current_step]
        position = self.actions[action] 

        reward = position * price_change - 0.01 * abs(position) * self.prices[self.current_step]
        self.position = position
        self.current_step = next_step

        if self.current_step >= self.max_steps:
            self.done = True

        return reward, self.done

    def print_current_state(self):
        print(f"Step: {self.current_step}, Price: {self.prices[self.current_step]:.3f}, Position: {self.position}")

    def init_policy(self):
        policy = {}
        for t in range(self.length):
            for p in [-1, 0, 1]:
                policy[(t, p)] = {a: 1 / len(self.actions) for a in self.actions}
        return policy

# %%
stock_env = AutoregressiveStockEnv(max_steps=99)

current_state = stock_env.get_state()
print(f"Initial state: {current_state}")
stock_env.print_current_state()

if stock_env.max_steps <= 0:
    print("Invalid time steps")

while not stock_env.done and stock_env.current_step < stock_env.max_steps:
    action_probabilities = 1/3 * np.ones(3)  # short, neutral, long
    action = np.random.choice(list(stock_env.actions.keys()), p=action_probabilities)

    reward, done = stock_env.step(action)
    new_state = stock_env.get_state()

    print(f"Step {stock_env.current_step}: s {current_state}, a {action} -> s' {new_state}, r {reward:.4f}")
    stock_env.print_current_state()

    if done:
        print(f"Terminated after {stock_env.current_step} steps (end of time or episode)")

    current_state = new_state
# Out:
# Initial state: (0, 0)
# Step: 0, Price: 1.015, Position: 0
# Step 1: s (0, 0), a neutral -> s' (1, 0), r -0.0000
# Step: 1, Price: 0.938, Position: 0
# Step 2: s (1, 0), a short -> s' (2, -1), r -0.0111
# Step: 2, Price: 0.940, Position: -1
# Step 3: s (2, -1), a neutral -> s' (3, 0), r 0.0000
# Step: 3, Price: 0.981, Position: 0
# Step 4: s (3, 0), a short -> s' (4, -1), r 0.0378
# Step: 4, Price: 0.933, Position: -1
# Step 5: s (4, -1), a neutral -> s' (5, 0), r 0.0000
# Step: 5, Price: 1.013, Position: 0
# Step 6: s (5, 0), a short -> s' (6, -1), r 0.0418
# Step: 6, Price: 0.961, Position: -1
# Step 7: s (6, -1), a short -> s' (7, -1), r 0.0318
# Step: 7, Price: 0.920, Position: -1
# Step 8: s (7, -1), a long -> s' (8, 1), r 0.0305
# Step: 8, Price: 0.959, Position: 1
# Step 9: s (8, 1), a neutral -> s' (9, 0), r -0.0000
# Step: 9, Price: 0.930, Position: 0
# Step 10: s (9, 0), a neutral -> s' (10, 0), r 0.0000
# Step: 10, Price: 1.009, Position: 0
# Step 11: s (10, 0), a long -> s' (11, 1), r 0.0453
# Step: 11, Price: 1.064, Position: 1
# Step 12: s (11, 1), a short -> s' (12, -1), r -0.0081
# Step: 12, Price: 1.062, Position: -1
# Step 13: s (12, -1), a long -> s' (13, 1), r -0.0344
# Step: 13, Price: 1.038, Position: 1
# Step 14: s (13, 1), a neutral -> s' (14, 0), r -0.0000
# Step: 14, Price: 0.979, Position: 0
# Step 15: s (14, 0), a neutral -> s' (15, 0), r 0.0000
# Step: 15, Price: 1.050, Position: 0
# Step 16: s (15, 0), a short -> s' (16, -1), r -0.0097
# Step: 16, Price: 1.049, Position: -1
# Step 17: s (16, -1), a short -> s' (17, -1), r -0.0402
# Step: 17, Price: 1.079, Position: -1
# Step 18: s (17, -1), a short -> s' (18, -1), r -0.0111
# Step: 18, Price: 1.079, Position: -1
# Step 19: s (18, -1), a neutral -> s' (19, 0), r 0.0000
# Step: 19, Price: 1.098, Position: 0
# Step 20: s (19, 0), a short -> s' (20, -1), r -0.0574
# Step: 20, Price: 1.144, Position: -1
# Step 21: s (20, -1), a long -> s' (21, 1), r -0.0182
# Step: 21, Price: 1.137, Position: 1
# Step 22: s (21, 1), a neutral -> s' (22, 0), r 0.0000
# Step: 22, Price: 1.152, Position: 0
# Step 23: s (22, 0), a short -> s' (23, -1), r -0.1175
# Step: 23, Price: 1.258, Position: -1
# Step 24: s (23, -1), a neutral -> s' (24, 0), r 0.0000
# Step: 24, Price: 1.352, Position: 0
# Step 25: s (24, 0), a long -> s' (25, 1), r 0.0212
# Step: 25, Price: 1.387, Position: 1
# Step 26: s (25, 1), a short -> s' (26, -1), r -0.0238
# Step: 26, Price: 1.397, Position: -1
# Step 27: s (26, -1), a long -> s' (27, 1), r -0.0590
# Step: 27, Price: 1.352, Position: 1
# Step 28: s (27, 1), a neutral -> s' (28, 0), r -0.0000
# Step: 28, Price: 1.236, Position: 0
# Step 29: s (28, 0), a neutral -> s' (29, 0), r 0.0000
# Step: 29, Price: 1.294, Position: 0
# Step 30: s (29, 0), a neutral -> s' (30, 0), r -0.0000
# Step: 30, Price: 1.193, Position: 0
# Step 31: s (30, 0), a short -> s' (31, -1), r -0.0750
# Step: 31, Price: 1.256, Position: -1
# Step 32: s (31, -1), a short -> s' (32, -1), r 0.0254
# Step: 32, Price: 1.218, Position: -1
# Step 33: s (32, -1), a neutral -> s' (33, 0), r -0.0000
# Step: 33, Price: 1.207, Position: 0
# Step 34: s (33, 0), a long -> s' (34, 1), r 0.0937
# Step: 34, Price: 1.312, Position: 1
# Step 35: s (34, 1), a short -> s' (35, -1), r -0.0547
# Step: 35, Price: 1.354, Position: -1
# Step 36: s (35, -1), a short -> s' (36, -1), r 0.0137
# Step: 36, Price: 1.327, Position: -1
# Step 37: s (36, -1), a short -> s' (37, -1), r 0.0462
# Step: 37, Price: 1.267, Position: -1
# Step 38: s (37, -1), a short -> s' (38, -1), r 0.0392
# Step: 38, Price: 1.215, Position: -1
# Step 39: s (38, -1), a short -> s' (39, -1), r -0.1134
# Step: 39, Price: 1.317, Position: -1
# Step 40: s (39, -1), a neutral -> s' (40, 0), r 0.0000
# Step: 40, Price: 1.441, Position: 0
# Step 41: s (40, 0), a neutral -> s' (41, 0), r -0.0000
# Step: 41, Price: 1.326, Position: 0
# Step 42: s (41, 0), a short -> s' (42, -1), r -0.0577
# Step: 42, Price: 1.371, Position: -1
